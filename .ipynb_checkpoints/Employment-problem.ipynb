# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
import os

# %%
current_directory = os.getcwd()

# %%
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: C:\Users\asus\Desktop\pandas2

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
db.shape
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 db.shape
#
# NameError: name 'db' is not defined

# %%
df.shape

# %%
df.info()

# %%
pd.set_option('display.max_columns',85)

# %%
df

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
schema_df

# %%
pd.set_option('display_max_row',30)

# %%
pd.set_option('display.max_row',40)

# %%
schema_df

# %%
pd.set_option('display.max_rows',40)

# %%
schema_df

# %%
pd.set_option('display.max_rows',40)

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',40)

# %%
schema_df

# %%
pd.set_option('display.max_rows',85)

# %%
df.head

# %%
df.head(10)

# %%
df.tail()

# %%
people = {
    "first" : ["Corey","Jane","John"],
    "last":["Schafer","Doe","Doe"],
    "email":["CoreyMschafer@gmail.com","JaneDoe@email.com","JohnDoe@email.com"]
}

# %%
people["first"]

# %%
people['last
']

# %%
people["last"]

# %%
people.first

# %%
people.first

# %%
df pd.DataFrame(people)

# %%
df = pd.DataFrma(people)

# %%
df = pd.Data.Frame(people)

# %%
df = pd.DataFrame(people)

# %%
df

# %%
df["email"]

# %%
type(df["email"])

# %%
type(df)

# %%
df.email

# %%
people.email

# %%
df[['last','email']]

# %%
def.columns

# %%
df.columns

# %%
df.iloc

# %%
df.iloc[0]

# %%
df[[0,1]]

# %%
df.iloc[[0,1]]

# %%
df.iloc[[0,1],2]

# %%
df.loc[0]

# %%
df.loc[[0,1],2]

# %%
df.loc[[0,1],'email']

# %%
df.loc[[O,1],2]

# %%
df.loc[[0,1],2]

# %%
df.iloc[[0,1],[0,1]]

# %%
df.loc[[0,1],['email','last']]

# %%
df.shape

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
df.columns

# %%
df['Q120']

# %%
df['Q120'].value_counts()

# %%
df['age']

# %%
df['Age']

# %%
df['Age'].value_counts()

# %%
df.loc[0,2]

# %%
def.loc[[0,2],['Q120','Age']]

# %%
df.loc[[0,2],['Q120','Age']]

# %%
df.loc[0:2,'Q120':'Age']

# %%
print(people)

# %%
print(people)

# %%
print('mohamed')

# %%
print(people)

# %%
print(df)

# %%
df.info()

# %%
df.shapa()

# %%
df.shape()

# %%
df.columns

# %%
df.iloc[]

# %%
df.loc[1]

# %%
n=1

# %%
n+=1

# %%
n+=1

# %%
print(n)

# %%
df.set_index('email')

# %%
df.set_index('last')

# %%
df

# %%
df.set_index('email',inplace=True)

# %%
df

# %%
df.index

# %%
df.loc['CoreyMschafer@gmail.com','last']

# %%
df.loc[0]

# %%
df.iloc[0]

# %%
df.reset_index(inplace=True)

# %%
df

# %%
df.loc[0]

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',80)

# %%
df.head()

# %%
df = pd.read_csv('survey_results_public.csv',index_col='Responseid')

# %%
df = pd.read_csv('survey_results_public.csv',index_col='Respondent')

# %%
df

# %%
df = pd.read_csv('survey_results_public.csv',index_col='ResponseId')

# %%
df

# %%
df.loc[0]

# %%
df.loc[1]

# %%
schema_df

# %%
schema_df = pd.read_csv('survey_results_schema.csv',index_col='qname')

# %%
schema_df

# %%
schema_df.loc['PurchaseInfluence','question']

# %%
schema_df.loc['MgrIdiot']

# %%
schema_df.sort_index()

# %%
schema_df.sort_index(ascending=False)

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df

# %%
schema_df.sort_index(ascending=False,inplace=True)

# %%
schema_df.reset_index(drop=True)

# %%
schema_df

# %%
people = {
    "first":['Corey','Jane','John'],
    'last':['Schafer','Doe','Doe'],
    'email':['CoreyMSchafer@gmail.com','JaneDoe@email.com','JohnDoe@email.com']
}

# %%
df_p = pd.DataFrame(people)
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df_p

# %%
df_p['last']=='Doe'

# %%
filt = df_p['last'] =='Doe'

# %%
filt

# %%
print(filt)

# %%
df_p[filt]

# %%
df_p.loc(filt)

# %%
df_p.loc[filt]

# %%
df_p[filt]

# %%
people[filt]

# %%
people

# %%
people['last'=='Doe']

# %%
df.loc[filt,'email']

# %%
df_p.loc[filt,'email']

# %%
filt = df['last']=='Doe'& df['first']=='john']

# %%
filt = df['last']=='Doe'& df['first']=='john'

# %%
filt = (df['last']=='Doe') & (df['first']=='john')

# %%
filt = (df_p['last']=='Doe') & (df_p['first']=='John')

# %%
filt

# %%
df.loc[-filt,'email']

# %%
df_p[~filt,'email']

# %%
df_p.loc[~filt]

# %%
df_p.loc[filt]

# %%
df

# %%
df.set_option('display.max_rows',80)

# %%
pd.set_option('display.max_rows',80)

# %%
df

# %%
pd.set_option('display.max_rows',180)

# %%
df

# %%
df

# %%
print('mohamed')

# %%
df

# %%
df.set_option('display.max_rows',800000)

# %%
df.set_option('display.max_rows',90000)

# %%
pd.set_option('display.max_rows',90)

# %%
print('mohamed')
# Out:
# mohamed

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
pd.set_option('display.max_columns',85)

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
filt = 'CompTotal' > 2.000000e+05
# Out:
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 filt = 'CompTotal' > 2.000000e+05
#
# TypeError: '>' not supported between instances of 'str' and 'float'

# %%
filt = df['CompTotal'] >2.000000e+9

# %%
df[filt].count()
# Out:
# ResponseId                             86
# Q120                                   86
# MainBranch                             86
# Age                                    86
# Employment                             86
# RemoteWork                             85
# CodingActivities                       85
# EdLevel                                86
# LearnCode                              85
# LearnCodeOnline                        71
# LearnCodeCoursesCert                   48
# YearsCode                              85
# YearsCodePro                           85
# DevType                                85
# OrgSize                                86
# PurchaseInfluence                      86
# TechList                               56
# BuyNewTool                             85
# Country                                86
# Currency                               86
# CompTotal                              86
# LanguageHaveWorkedWith                 86
# ...

# %%
df[filt].lenght
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\3386822784.py in ?()
# ----> 1 df[filt].lenght
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'lenght'

# %%
length([2,3])
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 length([2,3])
#
# NameError: name 'length' is not defined

# %%
len(df[filt])
# Out:
# 86

# %%
df.loc[filt]
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 142           143  I agree                     I am a developer by profession
# 747           748  I agree                     I am a developer by profession
# 946           947  I agree                     I am a developer by profession
# 1140         1141  I agree                     I am a developer by profession
# 1369         1370  I agree                     I am a developer by profession
# 2559         2560  I agree                     I am a developer by profession
# 2648         2649  I agree                     I am a developer by profession
# 2887         2888  I agree                     I am a developer by profession
# 4504         4505  I agree                     I am a developer by profession
# 5043         5044  I agree                     I am a developer by profession
# 5216         5217  I agree                     I am a developer by profession
# ...

# %%
df.loc(filt,['Age',	'Employment'])
# Out:
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df.loc(filt,['Age',	'Employment'])
#
# TypeError: _LocationIndexer.__call__() takes from 1 to 2 positional arguments but 3 were given

# %%
df.loc(filt,['Age','Employment'])
# Out:
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df.loc(filt,['Age','Employment'])
#
# TypeError: _LocationIndexer.__call__() takes from 1 to 2 positional arguments but 3 were given

# %%
df.loc(filt,'Age')
# Out:
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df.loc(filt,'Age')
#
# TypeError: _LocationIndexer.__call__() takes from 1 to 2 positional arguments but 3 were given

# %%
df.loc[filt,['Age',	'Employment']]
# Out:
#                       Age                                         Employment
# 142       18-24 years old                                Employed, full-time
# 747       35-44 years old  Independent contractor, freelancer, or self-em...
# 946       25-34 years old  Employed, full-time;Independent contractor, fr...
# 1140      25-34 years old                                Employed, full-time
# 1369      25-34 years old                                Employed, full-time
# 2559      25-34 years old                                Employed, full-time
# 2648      25-34 years old                                Employed, full-time
# 2887      25-34 years old                                Employed, full-time
# 4504      25-34 years old                                Employed, full-time
# 5043      18-24 years old                                Employed, full-time
# 5216      18-24 years old                                Employed, full-time
# ...

# %%
filt = ['Age'].isin(['18-24 years old',	'35-44 years old'])
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 filt = ['Age'].isin(['18-24 years old',	'35-44 years old'])
#
# AttributeError: 'list' object has no attribute 'isin'

# %%
filt = df['Age'].isin(['18-24 years old',	'35-44 years old'])

# %%
filt
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 89179    False
# 89180     True
# 89181    False
# 89182    False
# 89183     True
# Name: Age, Length: 89184, dtype: bool

# %%
len(df[filt])
# Out:
# 38463

# %%
df['LanguageWorkedWith']
# Out:
# ------------------------------------------------------------
# KeyError                   Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LanguageWorkedWith'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                   Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df['LanguageWorkedWith']
#
# ...

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df['LanguageWorkedWith']
# Out:
# ------------------------------------------------------------
# KeyError                   Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LanguageWorkedWith'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                   Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df['LanguageWorkedWith']
#
# ...

# %%
df['LanguageHaveWorkedWith']
# Out:
# 0                                                      NaN
# 1                               HTML/CSS;JavaScript;Python
# 2                               Bash/Shell (all shells);Go
# 3        Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 4                           HTML/CSS;JavaScript;TypeScript
#                                ...
# 89179              HTML/CSS;Java;JavaScript;SQL;TypeScript
# 89180                                 Dart;Java;Python;SQL
# 89181    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89182    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# 89183                      C#;Go;JavaScript;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 89184, dtype: object

# %%
filt=df['LanguageHaveWorkedWith'].str.contains('Jave')

# %%
filt
# Out:
# 0          NaN
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 89179    False
# 89180    False
# 89181    False
# 89182    False
# 89183    False
# Name: LanguageHaveWorkedWith, Length: 89184, dtype: object

# %%
df[filt]
# Out:
# ------------------------------------------------------------
# ValueError                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df[filt]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:4080, in DataFrame.__getitem__(self, key)
#    4077     return self.where(key)
#    4079 # Do we have a (boolean) 1d indexer?
# -> 4080 if com.is_bool_indexer(key):
#    4081     return self._getitem_bool_array(key)
#    4083 # We are left with two options: a single key, and a collection of keys,
#    4084 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\common.py:136, in is_bool_indexer(key)
#     132     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133     if lib.is_bool_array(key_array, skipna=True):
#     134         # Don't raise on e.g. ["A", "B", np.nan], see
# ...

# %%
df.loc[filt]
# Out:
# ------------------------------------------------------------
# ValueError                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df.loc[filt]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1412, in _LocIndexer._getitem_axis(self, key, axis)
#    1410     self._validate_key(key, axis)
#    1411     return self._get_slice_axis(key, axis=axis)
# -> 1412 elif com.is_bool_indexer(key):
#    1413     return self._getbool_axis(key, axis=axis)
#    1414 elif is_list_like_indexer(key):
#    1415     # an iterable multi-selection
#
# ...

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.loc[filt]
# Out:
# ------------------------------------------------------------
# ValueError                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df.loc[filt]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1412, in _LocIndexer._getitem_axis(self, key, axis)
#    1410     self._validate_key(key, axis)
#    1411     return self._get_slice_axis(key, axis=axis)
# -> 1412 elif com.is_bool_indexer(key):
#    1413     return self._getbool_axis(key, axis=axis)
#    1414 elif is_list_like_indexer(key):
#    1415     # an iterable multi-selection
#
# ...

# %%
filt=df['LanguageHaveWorkedWith'].str.contains('Java',na=True)

# %%
df.loc[filt,'LanguageHaveWorkedWith']
# Out:
# 0                                                      NaN
# 1                               HTML/CSS;JavaScript;Python
# 3        Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 4                           HTML/CSS;JavaScript;TypeScript
# 5        Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...
#                                ...
# 89178                                JavaScript;TypeScript
# 89179              HTML/CSS;Java;JavaScript;SQL;TypeScript
# 89180                                 Dart;Java;Python;SQL
# 89182    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# 89183                      C#;Go;JavaScript;SQL;TypeScript
# Name: LanguageHaveWorkedWith, Length: 65682, dtype: object

# %%
df_p
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 df_p
#
# NameError: name 'df_p' is not defined

# %%
df_p.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df_p.columns = ['first_name','last_name','email']

# %%
df_p
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df_p.columns = [x.upper() for x in  df_p.columns]

# %%
df_p
# Out:
#   FIRST_NAME LAST_NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df['FIRST_NAME']
# Out:
# ------------------------------------------------------------
# KeyError                   Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FIRST_NAME'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                   Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 df['FIRST_NAME']
#
# ...

# %%
df['EMAIL']
# Out:
# ------------------------------------------------------------
# KeyError                   Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EMAIL'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                   Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 df['EMAIL']
#
# ...

# %%
df.loc['EMAIL']
# Out:
# ------------------------------------------------------------
# KeyError                   Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 df.loc['EMAIL']
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
# ...

# %%
df
# Out:
#        RESPONSEID     Q120                      MAINBRANCH  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       AGE                                         EMPLOYMENT  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df_p
# Out:
#   FIRST_NAME LAST_NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df_p.FIRST_NAME
# Out:
# 0    Corey
# 1     Jane
# 2     John
# Name: FIRST_NAME, dtype: object

# %%
df_p.columns = df_p.columns.str.replace('_',' ')

# %%
df_p
# Out:
#   FIRST NAME LAST NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df_p
# Out:
#   FIRST NAME LAST NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.columns.replace(' ','_')
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 df.columns.replace(' ','_')
#
# AttributeError: 'Index' object has no attribute 'replace'

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df_p.columns = df_p.columns.str.replace(' ','_')

# %%
df_p
# Out:
#   FIRST_NAME LAST_NAME                    EMAIL
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df_p.columns = [x.lower() for x in df.columns]
# Out:
# ------------------------------------------------------------
# ValueError                 Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 df_p.columns = [x.lower() for x in df.columns]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:6310, in NDFrame.__setattr__(self, name, value)
#    6308 try:
#    6309     object.__getattribute__(self, name)
# -> 6310     return object.__setattr__(self, name, value)
#    6311 except AttributeError:
#    6312     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:813, in NDFrame._set_axis(self, axis, labels)
#     808 """
#     809 This is called from the cython code when we set the `index` attribute
#     810 directly, e.g. `series.index = [1, 2, 3]`.
#     811 """
#     812 labels = ensure_index(labels)
# --> 813 self._mgr.set_axis(axis, labels)
#     814 self._clear_item_cache()
#
# ...

# %%
df_p.columns = [x.lower() for x in df_p.columns]

# %%
df_p
# Out:
#   first_name last_name                    email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.rename(columns={'first_name':'first','last_name':'last'})
# Out:
#        responseid     q120                      mainbranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       age                                         employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df_p.rename(columns={'first_name':'first','last_name':'last'})
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df_p.columns = ['First_name','Last_name','Email']

# %%
df_p
# Out:
#   First_name Last_name                    Email
# 0      Corey   Schafer  CoreyMSchafer@gmail.com
# 1       Jane       Doe        JaneDoe@email.com
# 2       John       Doe        JohnDoe@email.com

# %%
df.rename(columns = {'First_name':'first','Last_name':'last'})
# Out:
#        responseid     q120                      mainbranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       age                                         employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df_p.rename(columns = {'First_name':'first','Last_name':'last'},inplace=True)

# %%
df_p
# Out:
#    first     last                    Email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.loc[2]
# Out:
# responseid                                                                             3
# q120                                                                             I agree
# mainbranch                                                I am a developer by profession
# age                                                                      45-54 years old
# employment                                                           Employed, full-time
# remotework                                          Hybrid (some remote, some in-person)
# codingactivities                       Hobby;Professional development or self-paced l...
# edlevel                                     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# learncode                              Books / Physical media;Colleague;On the job tr...
# learncodeonline                        Formal documentation provided by the owner of ...
# ...

# %%
df_p.loc[2]
# Out:
# first                 John
# last                   Doe
# Email    JohnDoe@email.com
# Name: 2, dtype: object

# %%
df.loc[2] = ['John','Smith','JohnSmith@email.com']
# Out:
# ------------------------------------------------------------
# ValueError                 Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 df.loc[2] = ['John','Smith','JohnSmith@email.com']
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexing.py:1942, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1939 # align and set the values
#    1940 if take_split_path:
#    1941     # We have to operate column-wise
# -> 1942     self._setitem_with_indexer_split_path(indexer, value, name)
#    1943 else:
#    1944     self._setitem_single_block(indexer, value, name)
#
# ...

# %%
df_p.loc[2] = ['John','Smith','JohnSmith@email.com']

# %%
df_p
# Out:
#    first     last                    Email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith      JohnSmith@email.com

# %%
df_p.set_index('Email')
# Out:
#                          first     last
# Email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnSmith@email.com       John    Smith

# %%
df_p.reset_index()
# Out:
#    index  first     last                    Email
# 0      0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1      1   Jane      Doe        JaneDoe@email.com
# 2      2   John    Smith      JohnSmith@email.com

# %%
df_p.set_index('index')
# Out:
# ------------------------------------------------------------
# KeyError                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\2014143291.py in ?()
# ----> 1 df_p.set_index('index')
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6105                     if not found:
#    6106                         missing.append(col)
#    6107
#    6108         if missing:
# -> 6109             raise KeyError(f"None of {missing} are in the columns")
#    6110
#    6111         if inplace:
#    6112             frame = self
#
# KeyError: "None of ['index'] are in the columns"

# %%
df_p
# Out:
#    first     last                    Email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John    Smith      JohnSmith@email.com

# %%
df.loc[2,['last','email']] = ['mohamed','mohamedsemai860@gmail.com']

# %%
df_p.loc[2,['last','Email']] = ['mohamed','mohamedsemai860@gmail.com']

# %%
df_p
# Out:
#    first     last                      Email                      email
# 0  Corey  Schafer    CoreyMSchafer@gmail.com                        NaN
# 1   Jane      Doe          JaneDoe@email.com                        NaN
# 2   John  mohamed  mohamedsemai860@gmail.com  mohamedsemai860@gmail.com

# %%
df.loc[2,'last'] = 'Smith'

# %%
df
# Out:
#        responseid     q120                      mainbranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       age                                         employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df_p.loc[2,'last'] = 'Smith'

# %%
df_p
# Out:
#    first     last                      Email                      email
# 0  Corey  Schafer    CoreyMSchafer@gmail.com                        NaN
# 1   Jane      Doe          JaneDoe@email.com                        NaN
# 2   John    Smith  mohamedsemai860@gmail.com  mohamedsemai860@gmail.com

# %%
filt = (df_p['Email'] == 'JaneDoe@email.com')

# %%
df_p[filt]['last']
# Out:
# 1    Doe
# Name: last, dtype: object

# %%
df_p.loc[filt,'last']='Smith'

# %%
df_p
# Out:
#    first     last                      Email                      email
# 0  Corey  Schafer    CoreyMSchafer@gmail.com                        NaN
# 1   Jane    Smith          JaneDoe@email.com                        NaN
# 2   John    Smith  mohamedsemai860@gmail.com  mohamedsemai860@gmail.com

# %%
df['email'].str.lower()
# Out:
# 0                              NaN
# 1                              NaN
# 2        mohamedsemai860@gmail.com
# 3                              NaN
# 4                              NaN
#                    ...
# 89179                          NaN
# 89180                          NaN
# 89181                          NaN
# 89182                          NaN
# 89183                          NaN
# Name: email, Length: 89184, dtype: object

# %%
df_p['Email'].str.lower()
# Out:
# 0      coreymschafer@gmail.com
# 1            janedoe@email.com
# 2    mohamedsemai860@gmail.com
# Name: Email, dtype: object

# %%
df_p.rename({'Email':'email'])
# Out:
#   Cell In[153], line 1
#     df_p.rename({'Email':'email'])
#                                 ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '{'

# %%
df_p.rename({'Email':'email'})
# Out:
#    first     last                      Email                      email
# 0  Corey  Schafer    CoreyMSchafer@gmail.com                        NaN
# 1   Jane    Smith          JaneDoe@email.com                        NaN
# 2   John    Smith  mohamedsemai860@gmail.com  mohamedsemai860@gmail.com

# %%
df_p
# Out:
#    first     last                      Email                      email
# 0  Corey  Schafer    CoreyMSchafer@gmail.com                        NaN
# 1   Jane    Smith          JaneDoe@email.com                        NaN
# 2   John    Smith  mohamedsemai860@gmail.com  mohamedsemai860@gmail.com

# %%
df_p.rename({'last':'Last'})
# Out:
#    first     last                      Email                      email
# 0  Corey  Schafer    CoreyMSchafer@gmail.com                        NaN
# 1   Jane    Smith          JaneDoe@email.com                        NaN
# 2   John    Smith  mohamedsemai860@gmail.com  mohamedsemai860@gmail.com

# %%
df_p.rename(columns={'Email':'email'})
# Out:
#    first     last                      email                      email
# 0  Corey  Schafer    CoreyMSchafer@gmail.com                        NaN
# 1   Jane    Smith          JaneDoe@email.com                        NaN
# 2   John    Smith  mohamedsemai860@gmail.com  mohamedsemai860@gmail.com

# %%
df_p.columns.email = 'Email'

# %%
df_p
# Out:
#    first     last                      Email                      email
# 0  Corey  Schafer    CoreyMSchafer@gmail.com                        NaN
# 1   Jane    Smith          JaneDoe@email.com                        NaN
# 2   John    Smith  mohamedsemai860@gmail.com  mohamedsemai860@gmail.com

# %%
df_p.rename(columns={'Email':'email'})
# Out:
#    first     last                      email                      email
# 0  Corey  Schafer    CoreyMSchafer@gmail.com                        NaN
# 1   Jane    Smith          JaneDoe@email.com                        NaN
# 2   John    Smith  mohamedsemai860@gmail.com  mohamedsemai860@gmail.com

# %%
df['email'] = df['email'].str.lower()

# %%
df = [x.str.lower() for x in df]
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 df = [x.str.lower() for x in df]
#
# Cell In[167], line 1, in <listcomp>(.0)
# ----> 1 df = [x.str.lower() for x in df]
#
# AttributeError: 'str' object has no attribute 'str'

# %%
df.email = [x.str.lower() for x in df.email]
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 df.email = [x.str.lower() for x in df.email]
#
# Cell In[168], line 1, in <listcomp>(.0)
# ----> 1 df.email = [x.str.lower() for x in df.email]
#
# AttributeError: 'float' object has no attribute 'str'

# %%
df['email'].apply(len)
# Out:
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# Cell In[169], line 1
# ----> 1 df['email'].apply(len)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
# ...

# %%
df['email'].apply(len)
# Out:
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# Cell In[170], line 1
# ----> 1 df['email'].apply(len)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
# ...

# %%
df_p['email'].apply(len)
# Out:
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# Cell In[171], line 1
# ----> 1 df_p['email'].apply(len)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
# ...

# %%
df_p['email'].apply(len)
# Out:
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 df_p['email'].apply(len)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
# ...

# %%
df_p = pd.DataFrame(people)

# %%
df_p['email'].apply(len)
# Out:
# 0    23
# 1    17
# 2    17
# Name: email, dtype: int64

# %%
df_p['email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
def update_email(email):
    return email.upper()

# %%
df_p['email'].apply(update_email)
# Out:
# 0    COREYMSCHAFER@GMAIL.COM
# 1          JANEDOE@EMAIL.COM
# 2          JOHNDOE@EMAIL.COM
# Name: email, dtype: object

# %%
df_p
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df_p['email'] = df_p['email'].apply(update_email)

# %%
df_p
# Out:
#    first     last                    email
# 0  Corey  Schafer  COREYMSCHAFER@GMAIL.COM
# 1   Jane      Doe        JANEDOE@EMAIL.COM
# 2   John      Doe        JOHNDOE@EMAIL.COM

# %%
df_p['email'] = df_p['email'].lower()
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\2370527420.py in ?()
# ----> 1 df_p['email'] = df_p['email'].lower()
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
df_p['email'] = df_p['email'].upper()
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\3436383599.py in ?()
# ----> 1 df_p['email'] = df_p['email'].upper()
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'upper'

# %%
df_p['email'] = df_p['email'].str.lower()

# %%
df_p.apply(len)
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df_p.apply(len,axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df_p.apply(pd.Series.min)
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %%
pd.Series.min(df_p['email'])
# Out:
# 'coreymschafer@gmail.com'

# %%
df_p
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John      Doe        johndoe@email.com

# %%
df_p.apply(lambda x:x.min())
# Out:
# first                      Corey
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %%
df_p.applymap(len)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_9104\546569973.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_p.applymap(len)
#    first  last  email
# 0      5     7     23
# 1      4     3     17
# 2      4     3     17

# %%
df_p.DataFrame.map(len)
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\3478418200.py in ?()
# ----> 1 df_p.DataFrame.map(len)
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'DataFrame'

# %%
df_p.applymap(len)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_9104\546569973.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_p.applymap(len)
#    first  last  email
# 0      5     7     23
# 1      4     3     17
# 2      4     3     17

# %%
df_p
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John      Doe        johndoe@email.com

# %%
df_p.map(len)
# Out:
#    first  last  email
# 0      5     7     23
# 1      4     3     17
# 2      4     3     17

# %%
df_p.apply(len)
# Out:
# first    3
# last     3
# email    3
# dtype: int64

# %%
df_p = df_p.str.lower()
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\461046826.py in ?()
# ----> 1 df_p = df_p.str.lower()
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
df_p.map(lambda x : x.upper())
# Out:
#    first     last                    email
# 0  COREY  SCHAFER  COREYMSCHAFER@GMAIL.COM
# 1   JANE      DOE        JANEDOE@EMAIL.COM
# 2   JOHN      DOE        JOHNDOE@EMAIL.COM

# %%
df_map(str.lower)
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# Cell In[206], line 1
# ----> 1 df_map(str.lower)
#
# NameError: name 'df_map' is not defined

# %%
df_p.map(lambda x : x.min())
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# Cell In[239], line 1
# ----> 1 df_p.map(lambda x : x.min())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:10455, in DataFrame.map(self, func, na_action, **kwargs)
#   10452 def infer(x):
#   10453     return x._map_values(func, na_action=na_action)
# > 10455 return self.apply(infer).__finalize__(self, "map")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:10361, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10347 from pandas.core.apply import frame_apply
#   10349 op = frame_apply(
#   10350     self,
#   10351     func=func,
#    (...)
#   10359     kwargs=kwargs,
#   10360 )
# > 10361 return op.apply().__finalize__(self, method="apply")
#
# ...

# %%
df['first']
# Out:
# ------------------------------------------------------------
# KeyError                   Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'first'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                   Traceback (most recent call last)
# Cell In[210], line 1
# ----> 1 df['first']
#
# ...

# %%
df['first'].map({'corey':'Chris','jane':'Mary'})
# Out:
# ------------------------------------------------------------
# KeyError                   Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'first'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                   Traceback (most recent call last)
# Cell In[209], line 1
# ----> 1 df['first'].map({'corey':'Chris','jane':'Mary'})
#
# ...

# %%
df_p['first'].apply({'corey':'mohamed'})
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# Cell In[211], line 1
# ----> 1 df_p['first'].apply({'corey':'mohamed'})
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\apply.py:1417, in SeriesApply.apply(self)
# ...

# %%
df_p['first'].map({'Corey':'mohamed'})
# Out:
# 0    mohamed
# 1        NaN
# 2        NaN
# Name: first, dtype: object

# %%
df_p
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John      Doe        johndoe@email.com

# %%
df['first'].replace({'Corey':'Mohamed'})
# Out:
# ------------------------------------------------------------
# KeyError                   Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'first'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                   Traceback (most recent call last)
# Cell In[219], line 1
# ----> 1 df['first'].replace({'Corey':'Mohamed'})
#
# ...

# %%
df_p['first'].replace({'Corey':'Mohamed'})
# Out:
# 0    Mohamed
# 1       Jane
# 2       John
# Name: first, dtype: object

# %%
df_p
# Out:
#    first     last                    email
# 0  Corey  Schafer  coreymschafer@gmail.com
# 1   Jane      Doe        janedoe@email.com
# 2   John      Doe        johndoe@email.com

# %%
df_p['first']=df_p['first'].replace({'Corey':'Mohamed'})

# %%
df_p
# Out:
#      first     last                    email
# 0  Mohamed  Schafer  coreymschafer@gmail.com
# 1     Jane      Doe        janedoe@email.com
# 2     John      Doe        johndoe@email.com

# %%
df.sort_value(by='last')
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\545496743.py in ?()
# ----> 1 df.sort_value(by='last')
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sort_value'

# %%
df_p.sort_value(by='last',ascending=False)
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\1723268872.py in ?()
# ----> 1 df_p.sort_value(by='last',ascending=False)
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sort_value'

# %%
df_p.sorts_value(by='last',ascending=False)
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\3671029479.py in ?()
# ----> 1 df_p.sorts_value(by='last',ascending=False)
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sorts_value'

# %%
df_p.sort_values(by='email',ascending=True,inplace=True)

# %%
df_p
# Out:
#      first     last                    email
# 0  Mohamed  Schafer  coreymschafer@gmail.com
# 1     Jane      Doe        janedoe@email.com
# 2     John      Doe        johndoe@email.com

# %%
dp_p.sort_index()
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# Cell In[234], line 1
# ----> 1 dp_p.sort_index()
#
# NameError: name 'dp_p' is not defined

# %%
df_p.sort_index()
# Out:
#      first     last                    email
# 0  Mohamed  Schafer  coreymschafer@gmail.com
# 1     Jane      Doe        janedoe@email.com
# 2     John      Doe        johndoe@email.com

# %%
df_p.map(str.min)
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# Cell In[236], line 1
# ----> 1 df_p.map(str.min)
#
# AttributeError: type object 'str' has no attribute 'min'

# %%
df_p.apply(lambda x:x.min())
# Out:
# first                       Jane
# last                         Doe
# email    coreymschafer@gmail.com
# dtype: object

# %%
df.sort_values(by=['last','first'])
# Out:
# ------------------------------------------------------------
# KeyError                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\4040518104.py in ?()
# ----> 1 df.sort_values(by=['last','first'])
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7155                 f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    7156                 f" != length of by ({len(by)})"
#    7157             )
#    7158         if len(by) > 1:
# -> 7159             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    7160
#    7161             # need to rewrap columns in Series to apply key function
#    7162             if key is not None:
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py in ?(.0)
# -> 7159         ...     key=lambda x: np.argsort(index_natsorted(df["time"]))
#
# ...

# %%
df.sort_values(by=['last','first'],ascending=True)
# Out:
# ------------------------------------------------------------
# KeyError                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\1666909495.py in ?()
# ----> 1 df.sort_values(by=['last','first'],ascending=True)
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7155                 f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    7156                 f" != length of by ({len(by)})"
#    7157             )
#    7158         if len(by) > 1:
# -> 7159             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    7160
#    7161             # need to rewrap columns in Series to apply key function
#    7162             if key is not None:
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py in ?(.0)
# -> 7159         ...     key=lambda x: np.argsort(index_natsorted(df["time"]))
#
# ...

# %%
df_p.sort_values(by=['last','first'])
# Out:
#      first     last                    email
# 1     Jane      Doe        janedoe@email.com
# 2     John      Doe        johndoe@email.com
# 0  Mohamed  Schafer  coreymschafer@gmail.com

# %%
df_p.sort_values(by=['last','first'],ascending=[False,True])
# Out:
#      first     last                    email
# 0  Mohamed  Schafer  coreymschafer@gmail.com
# 1     Jane      Doe        janedoe@email.com
# 2     John      Doe        johndoe@email.com

# %%
df.sort_index()
# Out:
#        responseid     q120                      mainbranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       age                                         employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df_p.sort_index()
# Out:
#      first     last                    email
# 0  Mohamed  Schafer  coreymschafer@gmail.com
# 1     Jane      Doe        janedoe@email.com
# 2     John      Doe        johndoe@email.com

# %%
df_p['last'].sort_values(ascending=False)
# Out:
# 0    Schafer
# 1        Doe
# 2        Doe
# Name: last, dtype: object

# %%
df.columns
# Out:
# Index(['responseid', 'q120', 'mainbranch', 'age', 'employment', 'remotework',
#        'codingactivities', 'edlevel', 'learncode', 'learncodeonline',
#        'learncodecoursescert', 'yearscode', 'yearscodepro', 'devtype',
#        'orgsize', 'purchaseinfluence', 'techlist', 'buynewtool', 'country',
#        'currency', 'comptotal', 'languagehaveworkedwith',
#        'languagewanttoworkwith', 'databasehaveworkedwith',
#        'databasewanttoworkwith', 'platformhaveworkedwith',
#        'platformwanttoworkwith', 'webframehaveworkedwith',
#        'webframewanttoworkwith', 'misctechhaveworkedwith',
#        'misctechwanttoworkwith', 'toolstechhaveworkedwith',
#        'toolstechwanttoworkwith', 'newcollabtoolshaveworkedwith',
#        'newcollabtoolswanttoworkwith', 'opsyspersonal_use',
#        'opsysprofessional_use', 'officestackasynchaveworkedwith',
#        'officestackasyncwanttoworkwith', 'officestacksynchaveworkedwith',
# ...

# %%
df.apply
# Out:
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# Cell In[255], line 1
# ----> 1 df['country'].nlargest(10)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:4243, in Series.nlargest(self, n, keep)
#    4145 def nlargest(
#    4146     self, n: int = 5, keep: Literal["first", "last", "all"] = "first"
#    4147 ) -> Series:
#    4148     """
#    4149     Return the largest `n` elements.
#    4150
#    (...)
#    4241     dtype: int64
#    4242     """
# -> 4243     return selectn.SelectNSeries(self, n=n, keep=keep).nlargest()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\methods\selectn.py:57, in SelectN.nlargest(self)
#      55 @final
#      56 def nlargest(self):
# ---> 57     return self.compute("nlargest")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\methods\selectn.py:96, in SelectNSeries.compute(self, method)
# ...

# %%
type(1)
# Out:
# int

# %%
filt = df.apply( lambda x : x=='responseid')
df[filt]
# Out:
#        responseid q120 mainbranch  age employment remotework codingactivities  \
# 0             NaN  NaN        NaN  NaN        NaN        NaN              NaN
# 1             NaN  NaN        NaN  NaN        NaN        NaN              NaN
# 2             NaN  NaN        NaN  NaN        NaN        NaN              NaN
# 3             NaN  NaN        NaN  NaN        NaN        NaN              NaN
# 4             NaN  NaN        NaN  NaN        NaN        NaN              NaN
# ...           ...  ...        ...  ...        ...        ...              ...
# 89179         NaN  NaN        NaN  NaN        NaN        NaN              NaN
# 89180         NaN  NaN        NaN  NaN        NaN        NaN              NaN
# 89181         NaN  NaN        NaN  NaN        NaN        NaN              NaN
# 89182         NaN  NaN        NaN  NaN        NaN        NaN              NaN
# 89183         NaN  NaN        NaN  NaN        NaN        NaN              NaN
#
# ...

# %%
integer_columns = df.select_dtypes(include='int').columns.tolist()

# %%
integer_columns
# Out:
# ['responseid']

# %%
df['responseid'].nlargest(10)
# Out:
# 89183    89184
# 89182    89183
# 89181    89182
# 89180    89181
# 89179    89180
# 89178    89179
# 89177    89178
# 89176    89177
# 89175    89176
# 89174    89175
# Name: responseid, dtype: int64

# %%
df.nlargest(10,'responseid')
df.nsmallest(10,'responseid')
# Out:
#    responseid     q120                                         mainbranch  \
# 0           1  I agree                                      None of these
# 1           2  I agree                     I am a developer by profession
# 2           3  I agree                     I am a developer by profession
# 3           4  I agree                     I am a developer by profession
# 4           5  I agree                     I am a developer by profession
# 5           6  I agree                     I am a developer by profession
# 6           7  I agree                     I am a developer by profession
# 7           8  I agree                     I am a developer by profession
# 8           9  I agree  I am not primarily a developer, but I write co...
# 9          10  I agree                     I am a developer by profession
#
#                age                                         employment  \
# 0  18-24 years old                                                NaN
# ...

# %%
df_p['first']+ ' ' +df_p['last']
# Out:
# 0    Mohamed Schafer
# 1           Jane Doe
# 2           John Doe
# dtype: object

# %%
df_p['full_name'] = df_p['first']+ ' ' +df_p['last']

# %%
df_p
# Out:
#      first     last                    email        full_name
# 0  Mohamed  Schafer  coreymschafer@gmail.com  Mohamed Schafer
# 1     Jane      Doe        janedoe@email.com         Jane Doe
# 2     John      Doe        johndoe@email.com         John Doe

# %%
df.drop(columns=['first','last'])
# Out:
# ------------------------------------------------------------
# KeyError                   Traceback (most recent call last)
# Cell In[301], line 1
# ----> 1 df.drop(columns=['first','last'])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
#    5570         axis=axis,
#    5571         index=index,
#    5572         columns=columns,
#    5573         level=level,
#    5574         inplace=inplace,
#    5575         errors=errors,
#    5576     )
#
# ...

# %%
df_p.drop(columns=['first','last'],inplace = True)

# %%
df_p
# Out:
#                      email        full_name
# 0  coreymschafer@gmail.com  Mohamed Schafer
# 1        janedoe@email.com         Jane Doe
# 2        johndoe@email.com         John Doe

# %%
df_p['full_name'].str.split(' ',expand=True)
# Out:
#          0        1
# 0  Mohamed  Schafer
# 1     Jane      Doe
# 2     John      Doe

# %%
df_p[['first','last']] = df_p['full_name'].str.split(' ',expand=True)

# %%
df_p['full_name'] = df_p[['first','last']].str.split(' ',expand=True)
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\4201826390.py in ?()
# ----> 1 df_p['full_name'] = df_p[['first','last']].str.split(' ',expand=True)
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
df['first']= df['first'] - 'Tony'
# Out:
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                  Traceback (most recent call last)
# Cell In[325], line 1
# ----> 1 df['first']= df['first'] - 'Tony'
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# ...

# %%
df
# Out:
#        responseid     q120                      mainbranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       age                                         employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df_p
# Out:
#                      email        full_name             first     last
# 0  coreymschafer@gmail.com  Mohamed Schafer  JohnTonyTonyTony  Schafer
# 1        janedoe@email.com         Jane Doe  JohnTonyTonyTony      Doe
# 2        johndoe@email.com         John Doe  JohnTonyTonyTony      Doe

# %%
df_p['first']= df_p['first'].apply(lambda x : x.replace('Tony',''))

# %%
df_p
# Out:
#                      email        full_name first     last
# 0  coreymschafer@gmail.com  Mohamed Schafer  John  Schafer
# 1        janedoe@email.com         Jane Doe  John      Doe
# 2        johndoe@email.com         John Doe  John      Doe

# %%
df_p['full_name'].split(' ')[0]
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\81735700.py in ?()
# ----> 1 df_p['full_name'].split(' ')[0]
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
df_p['full_name']
# Out:
# 0    Mohamed Schafer
# 1           Jane Doe
# 2           John Doe
# Name: full_name, dtype: object

# %%
df_p['first'] = df_p['full_name'].str.split(' ').apply(lambda x : x[0])

# %%
df_p
# Out:
#                      email        full_name    first     last
# 0  coreymschafer@gmail.com  Mohamed Schafer  Mohamed  Schafer
# 1        janedoe@email.com         Jane Doe     Jane      Doe
# 2        johndoe@email.com         John Doe     John      Doe

# %%
df_p.append({'first': 'Tony'}, ignore_index=True)
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\3015551015.py in ?()
# ----> 1 df_p.append({'first': 'Tony'}, ignore_index=True)
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
new_row = {'first': 'Tony'}
df_p = df_p.append(new_row, ignore_index=True)
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\2950408650.py in ?()
#       1 new_row = {'first': 'Tony'}
# ----> 2 df_p = df_p.append(new_row, ignore_index=True)
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df1 = df = pd.DataFrame({"a":[1, 2, 3, 4],
                        "b":[5, 6, 7, 8]})
 
# Creating the Second Dataframe using dictionary
df2 = pd.DataFrame({"a":[1, 2, 3],
                    "b":[5, 6, 7]})
 
# Print df1
print("Printing df1")
print(df1, "\n")
 
# Print df2
print("Printing df2")
df2
# Out:
# Printing df1
#    a  b
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8
#
# Printing df2
#    a  b
# 0  1  5
# 1  2  6
# 2  3  7

# %%
df1.append(df2)
# Out:
# ------------------------------------------------------------
# AttributeError             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\3062608662.py in ?()
# ----> 1 df1.append(df2)
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
df1._append(df2, ignore_index=True)
# Out:
#    a  b
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8
# 4  1  5
# 5  2  6
# 6  3  7

# %%
df_p= df_p._append({'first':'Tony'},ignore_index=True)

# %%
df['first'=='Tony']
# Out:
# ------------------------------------------------------------
# KeyError                   Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                   Traceback (most recent call last)
# Cell In[361], line 1
# ----> 1 df['first'=='Tony']
#
# ...

# %%
df_p['first'=='Tony']
# Out:
# ------------------------------------------------------------
# KeyError                   Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                   Traceback (most recent call last)
# Cell In[362], line 1
# ----> 1 df_p['first'=='Tony']
#
# ...

# %%
df_p['first']
# Out:
# 0    Mohamed
# 1       Jane
# 2       John
# Name: first, dtype: object

# %%
df_p[df_p['first']=='Tony'].apply(lambda x : True if x == False else True )
# Out:
# ------------------------------------------------------------
# ValueError                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\2359723320.py in ?()
# ----> 1 df_p[df_p['first']=='Tony'].apply(lambda x : True if x == False else True )
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py in ?(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10357             engine_kwargs=engine_kwargs,
#   10358             args=args,
#   10359             kwargs=kwargs,
#   10360         )
# > 10361         return op.apply().__finalize__(self, method="apply")
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\apply.py in ?(self)
#     912         # raw
#     913         elif self.raw:
#     914             return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
#     915
# --> 916         return self.apply_standard()
#
# ...

# %%
df_p
# Out:
#                      email        full_name    first     last
# 0  coreymschafer@gmail.com  Mohamed Schafer  Mohamed  Schafer
# 1        janedoe@email.com         Jane Doe     Jane      Doe
# 2        johndoe@email.com         John Doe     John      Doe

# %%
df.colo
